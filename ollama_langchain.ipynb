# %%
# !pip install langchain-ollama

# %%
from langchain_ollama import ChatOllama

# %%
llm=ChatOllama(
    model='llama3.2:3b',
    temperature=0.2
)

# %%
response=llm.invoke('capital city of india')

# %%
response.content
# Out:
# 'The capital city of India is New Delhi.'

# %%
from langchain_ollama import OllamaEmbeddings

embeddings=OllamaEmbeddings(

    model='embeddinggemma:latest'
)

# %%
query_result=embeddings.embed_query('what is langchain')

# %%
query_result
# Out:
# [-0.1718852,
#  0.022025734,
#  0.0161134,
#  0.020514408,
#  0.0042864196,
#  0.030234195,
#  0.0029248693,
#  0.037586957,
#  -0.0009068242,
#  -0.013784847,
#  -0.025075423,
#  -0.010707009,
#  0.04001404,
#  -0.031220656,
#  0.03460224,
#  -0.015667163,
#  0.049867634,
#  -0.03559381,
#  -0.047012452,
#  -0.008317229,
#  -0.037752982,
#  -0.008782333,
#  -0.035909556,
#  -0.032806776,
#  0.0436228,
#  -0.00726682,
#  0.044849683,
#  -0.06559745,
#  -0.00039466476,
#  -0.016930971,
#  0.044371072,
#  0.026846236,
#  -0.011205975,
#  -0.030548848,
#  0.012319717,
#  0.040652215,
#  5.1677263e-05,
#  0.0044672373,
#  0.0038445364,
#  -0.015646715,
#  -0.055626035,
#  0.06131181,
#  -0.01675401,
#  0.003869195,
#  0.00860362,
#  -0.086610354,
#  -0.040890947,
#  -0.0047860206,
#  0.030446239,
#  0.041306354,
#  -0.030124491,
#  -0.026467375,
#  -0.07498755,
#  -0.0048747114,
#  -0.039604176,
#  -0.033790063,
#  -0.05009886,
#  -0.045351017,
#  -0.019880595,
#  0.011486111,
# ...

# %%
doc_results=embeddings.embed_documents(['Document content 1','Document content 2'])
print(f'the embeddings length {len(doc_results)}')
# Out:
# the embeddings length 2

# %%
doc_results[0]
# Out:
# [-0.16097966,
#  0.0037913176,
#  0.009174582,
#  0.013051781,
#  0.023097688,
#  0.06545742,
#  -0.057058714,
#  0.035998497,
#  0.039225753,
#  -0.033947233,
#  0.014060986,
#  -0.018967012,
#  0.01762247,
#  -0.019591236,
#  0.07199048,
#  0.011416776,
#  0.008327413,
#  0.020185757,
#  -0.04551103,
#  0.0028961117,
#  0.03750493,
#  -0.005702682,
#  -0.040240474,
#  -0.035574622,
#  0.015162151,
#  0.056902863,
#  0.059743382,
#  -0.0014384277,
#  -0.0019726732,
#  -0.008994566,
#  -0.03499546,
#  0.002716014,
#  0.03503501,
#  0.030441225,
#  0.041922916,
#  0.051803373,
#  0.056751125,
#  -0.021382127,
#  -0.0033787466,
#  -0.0007082537,
#  -0.04361255,
#  0.10008809,
#  -0.038992804,
#  -0.03013466,
#  0.010286627,
#  -0.00040650295,
#  -0.04897775,
#  -0.023237115,
#  0.0950108,
#  -0.0016473581,
#  0.038858403,
#  -0.025261872,
#  -0.049330715,
#  -0.021832742,
#  -0.028624043,
#  -0.04565309,
#  -0.090856895,
#  0.024279801,
#  0.025167324,
#  0.04036491,
#  -0.008096279,
# ...
